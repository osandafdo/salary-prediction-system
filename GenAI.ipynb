# %%
# !pip install google-genai

# %%
from google import genai

def prompt_gemini(prompt_text: str) -> str:
    client = genai.Client(api_key="AIzaSyBvif6ZGrAA9Pwd7Fe4zYWwmRTHpJ2FpLQ")  # or rely on env var GEMINI_API_KEY
    resp = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=[
            {
                "parts": [
                    { "text": prompt_text }
                ]
            }
        ]
    )
    return resp.text

# %%
import logging

def safe_prompt_gemini(prompt_text: str) -> str:
    try:
        return prompt_gemini(prompt_text)
    except Exception as e:
        logging.error(f"Error in prompt_gemini: {e}")
        return "Sorry, there was an error processing your request."

# %%
# Define the data as a dictionary
data = {
    "ExperienceYears": 10,
    "Certifications": 2,
    "PreviousCompanies": 1,
    "Age": 35,
    "CompanySize": 200,
    "CommuterSupport": 0,
    "HealthInsurance": 1,
    "FlexibleHours": 1,
    "Gym": 0,
    "Bonus": 0,
    "StockOptions": 0,
    "Retirement": 0,
    "Gender_Female": False,
    "Gender_Male": True,
    "Gender_Non-binary": False,
    "RemoteOnsite_Hybrid": False,
    "RemoteOnsite_Onsite": True,
    "RemoteOnsite_Remote": False,
    "Industry_Consulting": False,
    "Industry_Finance": False,
    "Industry_Healthcare": False,
    "Industry_Retail": False,
    "Industry_Tech": True,
    "Education_Bachelors": True,
    "Education_Diploma": True,
    "Education_Masters": True,
    "Education_PhD": False,
    "Location_Australia": False,
    "Location_Germany": False,
    "Location_India": False,
    "Location_Sri Lanka": True,
    "Location_Sweden": False,
    "Location_UK": False,
    "Location_USA": False,
    "JobTitle_Data Engineer": False,
    "JobTitle_Data Scientist": False,
    "JobTitle_Fullstack Developer": False,
    "JobTitle_Lead Engineer": True,
    "JobTitle_Senior Software Engineer": False,
    "JobTitle_Software Architect": False,
    "JobTitle_Software Engineer": False
}

# Usage
result = safe_prompt_gemini('Predict the salary of a person with the following attributes: ' + str(data))
print(result)
# Out:
# Let's break down the attributes and their likely impact on salary:
#
# **Positive Factors:**
#
# *   **ExperienceYears: 10** (Very strong positive)
# *   **Age: 35** (Consistent with high experience)
# *   **Certifications: 2** (Adds value)
# *   **HealthInsurance: 1, FlexibleHours: 1** (Indicates a more established company, though these are benefits, they often correlate with better base pay)
# *   **Industry: Tech** (Generally higher salaries than other industries)
# *   **Education: Masters** (Highest degree, strong positive)
# *   **JobTitle: Lead Engineer** (Senior, leadership role, commands higher pay)
# *   **CompanySize: 200** (Medium-sized, often able to pay competitive salaries)
# *   **Gender_Male: True** (Historically, may sometimes correlate with higher pay, though ideally a neutral factor)
# *   **RemoteOnsite_Onsite: True** (Can sometimes command slightly higher pay or be neutral)
#
# **Negative/Neutral/Missing Factors:**
#
# *   **PreviousCompanies: 1** (Could be loyal or less varied experience; largely neutral for prediction but some argue less job hopping can mean less salary growth)
# *   **CommuterSupport: 0, Gym: 0** (Missing benefits, not a direct salary impact but suggests less comprehensive package)
# *   **Bonus: 0, StockOptions: 0, Retirement: 0** (These are significant parts of total compensation, especially in tech. Their absence means the *base salary* needs to carry more weight, but also might indicate a less generous overall compensation philosophy. This will significantly lower the *total compensation* compared to a role with these benefits, and might even slightly depress the base.)
#
# **Dominant Negative Factor:**
#
# *   **Location: Sri Lanka** (This is the *most critical* factor that will drastically pull down the salary compared to someone with similar qualifications in Western countries or even other Asian tech hubs like Singapore/Dubai. Salaries in Sri Lanka for tech roles, even senior ones, are significantly lower.)
#
# **Synthesis:**
#
# This individual has an excellent profile in terms of experience, education, industry, and job title. However, the location (Sri Lanka) is a major limiting factor for the absolute salary figure. The absence of common tech benefits like bonuses, stock options, and retirement plans also suggests a less generous overall package, which might mean the base salary isn't as high as it could be in a company offering those perks.
#
# Considering the high qualifications for the Sri Lankan market, this person would be among the top earners.
#
# *   A typical range for a highly skilled Senior/Lead Engineer in Sri Lanka can vary greatly but might be in the LKR 600,000 to LKR 1,000,000+ per month range (approx. LKR 7.2 million to 12 million+ per year).
# *   Converting to USD (using an approximate rate of 1 USD = 300 LKR):
#     *   LKR 7.2 million = ~$24,000 USD
#     *   LKR 12 million = ~$40,000 USD
#
# Given the specific attributes (10 years experience, Masters, Lead Engineer, Tech industry, 200 company size, but *no* bonus/stock/retirement), I'd place the base salary towards the higher end of the local market, but not at the absolute peak due to the missing benefits.
#
# **Predicted Salary:**
#
# I predict the base salary to be around **$35,000 USD per year**.
# (This equates to approximately LKR 10,500,000 per year or LKR 875,000 per month).
