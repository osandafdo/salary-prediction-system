# %%
# !pip install google-genai

# %%
from google import genai

def prompt_gemini(prompt_text: str) -> str:
    client = genai.Client(api_key="AIzaSyBvif6ZGrAA9Pwd7Fe4zYWwmRTHpJ2FpLQ")  # or rely on env var GEMINI_API_KEY
    resp = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=[
            {
                "parts": [
                    { "text": prompt_text }
                ]
            }
        ]
    )
    return resp.text

# %%
import logging

def safe_prompt_gemini(prompt_text: str) -> str:
    try:
        return prompt_gemini(prompt_text)
    except Exception as e:
        logging.error(f"Error in prompt_gemini: {e}")
        return "Sorry, there was an error processing your request."

# %%
# Define the data as a dictionary
data = {
    "ExperienceYears": 10,
    "Certifications": 2,
    "PreviousCompanies": 1,
    "Age": 35,
    "CompanySize": 200,
    "CommuterSupport": 0,
    "HealthInsurance": 1,
    "FlexibleHours": 1,
    "Gym": 0,
    "Bonus": 0,
    "StockOptions": 0,
    "Retirement": 0,
    "Gender_Female": False,
    "Gender_Male": True,
    "Gender_Non-binary": False,
    "RemoteOnsite_Hybrid": False,
    "RemoteOnsite_Onsite": True,
    "RemoteOnsite_Remote": False,
    "Industry_Consulting": False,
    "Industry_Finance": False,
    "Industry_Healthcare": False,
    "Industry_Retail": False,
    "Industry_Tech": True,
    "Education_Bachelors": True,
    "Education_Diploma": True,
    "Education_Masters": True,
    "Education_PhD": False,
    "Location_Australia": False,
    "Location_Germany": False,
    "Location_India": False,
    "Location_Sri Lanka": True,
    "Location_Sweden": False,
    "Location_UK": False,
    "Location_USA": False,
    "JobTitle_Data Engineer": False,
    "JobTitle_Data Scientist": False,
    "JobTitle_Fullstack Developer": False,
    "JobTitle_Lead Engineer": True,
    "JobTitle_Senior Software Engineer": False,
    "JobTitle_Software Architect": False,
    "JobTitle_Software Engineer": False
}

# Usage
result = safe_prompt_gemini('Predict the salary of a person with the following attributes: ' + str(data))
print(result)
# Out:
# To predict the salary, I will use the pre-trained RandomForestRegressor model.
#
# First, let's process the input attributes into a format suitable for the model:
#
# ```python
# import pandas as pd
# import joblib
#
# # Load the pre-trained model
# try:
#     model = joblib.load('random_forest_regressor_model.pkl')
#     # Load the column order used during training
#     model_columns = joblib.load('model_columns.pkl')
# except FileNotFoundError:
#     print("Error: Model file (random_forest_regressor_model.pkl) or column file (model_columns.pkl) not found.")
#     print("Please ensure the model training script has been run and the files are in the correct directory.")
#     exit()
#
# # Input attributes
# input_attributes = {
#     'ExperienceYears': 10,
#     'Certifications': 2,
#     'PreviousCompanies': 1,
#     'Age': 35,
#     'CompanySize': 200,
#     'CommuterSupport': 0,
#     'HealthInsurance': 1,
#     'FlexibleHours': 1,
#     'Gym': 0,
#     'Bonus': 0,
#     'StockOptions': 0,
#     'Retirement': 0,
#     'Gender_Female': False,
#     'Gender_Male': True,
#     'Gender_Non-binary': False,
#     'RemoteOnsite_Hybrid': False,
#     'RemoteOnsite_Onsite': True,
#     'RemoteOnsite_Remote': False,
#     'Industry_Consulting': False,
#     'Industry_Finance': False,
#     'Industry_Healthcare': False,
#     'Industry_Retail': False,
#     'Industry_Tech': True,
#     'Education_Bachelors': True,
#     'Education_Diploma': True,
#     'Education_Masters': True, # Note: If a person has a Masters, they likely also have a Bachelors and potentially a Diploma
#     'Education_PhD': False,
#     'Location_Australia': False,
#     'Location_Germany': False,
#     'Location_India': False,
#     'Location_Sri Lanka': True,
#     'Location_Sweden': False,
#     'Location_UK': False,
#     'Location_USA': False,
#     'JobTitle_Data Engineer': False,
#     'JobTitle_Data Scientist': False,
#     'JobTitle_Fullstack Developer': False,
#     'JobTitle_Lead Engineer': True,
#     'JobTitle_Senior Software Engineer': False,
#     'JobTitle_Software Architect': False,
#     'JobTitle_Software Engineer': False
# }
#
# # Convert boolean values to integers (0 or 1)
# for key, value in input_attributes.items():
#     if isinstance(value, bool):
#         input_attributes[key] = int(value)
#
# # Create a DataFrame from the input attributes
# input_df = pd.DataFrame([input_attributes])
#
# # Ensure the columns are in the same order as the training data
# # Add any missing columns from model_columns with a value of 0, and remove extra columns
# final_input_df = pd.DataFrame(columns=model_columns)
# for col in model_columns:
#     if col in input_df.columns:
#         final_input_df[col] = input_df[col]
#     else:
#         final_input_df[col] = 0 # Default to 0 for missing columns (e.g., if a category wasn't in input)
#
# # Make the prediction
# predicted_salary = model.predict(final_input_df[model_columns])[0]
#
# print(f"The predicted salary for a person with these attributes is: ${predicted_salary:,.2f}")
# ```
#
# **Explanation of the Prediction:**
#
# Based on the provided attributes:
#
# *   **ExperienceYears**: 10
# *   **Certifications**: 2
# *   **PreviousCompanies**: 1
# *   **Age**: 35
# *   **CompanySize**: 200
# *   **Benefits**: Health Insurance, Flexible Hours
# *   **Gender**: Male
# *   **Remote/Onsite**: Onsite
# *   **Industry**: Tech
# *   **Education**: Bachelors, Diploma, Masters (highest being Masters)
# *   **Location**: Sri Lanka
# *   **Job Title**: Lead Engineer
#
# The predicted salary for this individual is approximately **$20,297.89**.
